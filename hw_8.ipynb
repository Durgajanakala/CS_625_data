# %% [markdown]
# <a href="https://colab.research.google.com/github/Durgajanakala/CS_625_data/blob/main/hw_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **What is the average nightly price of each room type (shared, private) for superhost and non-superhost hosts on weekdays and weekends in Vienna?**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from matplotlib.ticker import FuncFormatter


# Load the datasets
import pandas as pd

# Load the weekdays dataset from Google Drive
weekdays_file_path = '/content/drive/MyDrive/vienna_weekdays.csv'
weekdays_df = pd.read_csv(weekdays_file_path)

# Load the weekends dataset from Google Drive
weekends_file_path = '/content/drive/MyDrive/vienna_weekends.csv'
weekends_df = pd.read_csv(weekends_file_path)

# Group the data by room type, host is superhost, and weekday/weekend
weekdays = weekdays_df.groupby(['room_type', 'host_is_superhost']).size().unstack().reset_index()
weekends = weekends_df.groupby(['room_type', 'host_is_superhost']).size().unstack().reset_index()

# Define custom colors (dark blue for weekdays, dark green for weekends)
my_colors_weekdays = ["#1F77B4", "#FF7F0E"]
my_colors_weekends = ["#8A2BE2", "#FF007F"]

# Set the custom color palette and font sizes
sns.set_palette(my_colors_weekdays)
sns.set(font_scale=1.2)

# Create a figure with a single subplot
fig, ax = plt.subplots(figsize=(18, 8))

# Plot the grouped bar chart showing the number of occurrences of each room type and host is superhost for weekdays and weekends
weekdays_by_type_status.plot(x="room_type", kind="bar", ax=ax, position=0, width=0.4, alpha=0.8, legend=False, color=my_colors_weekdays)
weekends_by_type_status.plot(x="room_type", kind="bar", ax=ax, position=1, width=0.4, alpha=0.8, legend=False, color=my_colors_weekends)

# Set the title, labels, and legend
ax.set_title('Room Type and Host is Superhost Count on Weekdays and Weekends', fontsize=16, fontweight='bold')
ax.set_xlabel('Room Type', fontsize=16, fontweight='bold')
ax.set_ylabel('Count', fontsize=16, fontweight='bold')
ax.legend(['Weekdays: Superhost', 'Weekdays: Non-Superhost', 'Weekends: Superhost', 'Weekends: Non-Superhost'], title='Host Status', fontsize=12, title_fontsize=12)

# Annotate the bars with exact count values and adjust the text position
for p in ax.patches:
    ax.annotate(str(int(p.get_height())), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
                textcoords='offset points')

# Add gridlines
ax.grid(True)

# Set the x-tick labels rotation
plt.xticks(rotation=45)


# Set a main title for the entire figure
fig.suptitle("Average Nightly Price of Each Room Type for Superhost and Non-Superhost Hosts on Weekdays and Weekends in Vienna", fontsize=20, fontweight='bold')

# Adjust the spacing between the subplots and the main title
plt.subplots_adjust(top=0.85, wspace=0.5)


# Show the plot
plt.show()
